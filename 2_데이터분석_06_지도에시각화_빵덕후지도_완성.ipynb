# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkGeunHae/dataAnalysis/blob/main/2_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_06_%EC%A7%80%EB%8F%84%EC%97%90%EC%8B%9C%EA%B0%81%ED%99%94_%EB%B9%B5%EB%8D%95%ED%9B%84%EC%A7%80%EB%8F%84_%EC%99%84%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 한글폰트 설정 및 라이브러리 임포트

# %%
# 코드 실행 후 재시작
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (11.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# # 필요한 라이브러리 import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 멧플롯립 한글폰트 지정
plt.rc('font', family='NanumBarunGothic')    # 코랩에서 사용
#plt.rc('font', family='Malgun Gothic')    # 윈도우에서 사용
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 빵덕후들의 지도
#  - 제주도 서귀포시의 제과점 위치 정보를 제공하는 지도 시각화

# %% [markdown]
# ## 파일 읽어서 데이터프레임 생성하기

# %%
import pandas as pd
df = pd.read_csv('제주특별자치도_서귀포시_제과점현황_20240401.csv', encoding='cp949')
df.head()
# Out:
#      업종명                          업소명                            소재지(도로명)  \
# 0  제과점영업           노베케이션(No Vacation)          제주특별자치도 서귀포시 표선면 민속해안로 635
# 1  제과점영업            그랜드파파(Grand papa)  제주특별자치도 서귀포시 태평로353번길 14, 1층 (서귀동)
# 2  제과점영업               위드윗(withwheat)          제주특별자치도 서귀포시 중앙로 261 (서홍동)
# 3  제과점영업                         허니제과        제주특별자치도 서귀포시 대정읍 서광남로 77, 1층
# 4  제과점영업  도트베이글팩토리(DOT BAGEL FACTORY)     제주특별자치도 서귀포시 서호호근로96번길 20 (서호동)
#
#                        소재지(지번)         위도          경도     데이터기준일자
# 0   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364  126.837714  2024-04-01
# 1      제주특별자치도 서귀포시 서귀동 829-5   33.246848  126.560673  2024-04-01
# 2      제주특별자치도 서귀포시 서홍동 166-5   33.267520  126.558177  2024-04-01
# 3  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342  126.301778  2024-04-01
# 4      제주특별자치도 서귀포시 서호동 325-1   33.255598  126.526362  2024-04-01

# %% [markdown]
# ## 데이터 구조 탐색하기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   업종명       167 non-null    object
#  1   업소명       167 non-null    object
#  2   소재지(도로명)  165 non-null    object
#  3   소재지(지번)   167 non-null    object
#  4   위도        167 non-null    float64
#  5   경도        167 non-null    float64
#  6   데이터기준일자   167 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 9.3+ KB

# %%
df[df['소재지(도로명)'].isnull()]
# Out:
#        업종명     업소명 소재지(도로명)                      소재지(지번)         위도  \
# 144  제과점영업    빵하우스      NaN      제주특별자치도 서귀포시 동홍동 645-3   33.252836
# 159  제과점영업  빙그레제과점      NaN  제주특별자치도 서귀포시 대정읍 하모리 824번지   33.221995
#
#              경도     데이터기준일자
# 144  126.570179  2024-04-01
# 159  126.254367  2024-04-01

# %%
#'업종명'컬럼의 데이터 확인하기
df['업종명'].value_counts()
# Out:
# 업종명
# 제과점영업    167
# Name: count, dtype: int64

# %%
# 결측치 데이터 확인하기
# df.isnull()
df.isnull().sum()  #count를 해도 됨
# Out:
# 업종명         0
# 업소명         0
# 소재지(도로명)    2
# 소재지(지번)     0
# 위도          0
# 경도          0
# 데이터기준일자     0
# dtype: int64

# %%
# 특정 컬럼의 결측치 확인
df[df['소재지(도로명)'].isnull()]
# df.loc[df['소재지(도로명)'].isnull()]
# Out:
#        업종명     업소명 소재지(도로명)                      소재지(지번)         위도  \
# 144  제과점영업    빵하우스      NaN      제주특별자치도 서귀포시 동홍동 645-3   33.252836
# 159  제과점영업  빙그레제과점      NaN  제주특별자치도 서귀포시 대정읍 하모리 824번지   33.221995
#
#              경도     데이터기준일자
# 144  126.570179  2024-04-01
# 159  126.254367  2024-04-01

# %% [markdown]
# ## 데이터 전처리하기

# %% [markdown]
# ### 이상치 확인하기
# - 수치형 값을 갖는 '위도','경도' 컬럼에 이상치가 있는지 boxplot으로 확인

# %%
import matplotlib.pyplot as plt

ax1 = plt.subplot(121) # (1) 첫 번째 공간에 axes 생성   1행2열1번째
ax1.boxplot(df['위도'])
ax2 = plt.subplot(122)
ax2.boxplot(df['경도'])
plt.show()

# %% [markdown]
# ### 불필요한 컬럼 삭제하기
# - '소재지(도로명)' 컬럼 대신 '소재지(지번)'을 사용하면 되기 때문에 이 컬럼은 삭제한다
# - '업종명', '데이터기준일자' 컬럼도 분석에 필요하지 않은 내용으로 보고 삭제한다.

# %%
df.drop(columns=['업종명', '소재지(도로명)', '데이터기준일자'], axis=1, inplace=True)
df.isnull().sum()
# Out:
# 업소명        0
# 소재지(지번)    0
# 위도         0
# 경도         0
# dtype: int64

# %%
df.head()
# Out:
#                            업소명                      소재지(지번)         위도  \
# 0           노베케이션(No Vacation)   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364
# 1            그랜드파파(Grand papa)      제주특별자치도 서귀포시 서귀동 829-5   33.246848
# 2               위드윗(withwheat)      제주특별자치도 서귀포시 서홍동 166-5   33.267520
# 3                         허니제과  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342
# 4  도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1   33.255598
#
#            경도
# 0  126.837714
# 1  126.560673
# 2  126.558177
# 3  126.301778
# 4  126.526362

# %% [markdown]
# ### 소재지(지번) 주소에서 읍,면,동 정보 추출하기

# %%
df['소재지(지번)'].str.split(' ').str[2]
# Out:
# 0      표선면
# 1      서귀동
# 2      서홍동
# 3      대정읍
# 4      서호동
#       ...
# 162    서귀동
# 163    서귀동
# 164    남원읍
# 165    대정읍
# 166    안덕면
# Name: 소재지(지번), Length: 167, dtype: object

# %%
df['읍면동'] = df['소재지(지번)'].str.split(' ').str[2]  #파생변수
df.head()
# Out:
#                            업소명                      소재지(지번)         위도  \
# 0           노베케이션(No Vacation)   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364
# 1            그랜드파파(Grand papa)      제주특별자치도 서귀포시 서귀동 829-5   33.246848
# 2               위드윗(withwheat)      제주특별자치도 서귀포시 서홍동 166-5   33.267520
# 3                         허니제과  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342
# 4  도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1   33.255598
#
#            경도  읍면동
# 0  126.837714  표선면
# 1  126.560673  서귀동
# 2  126.558177  서홍동
# 3  126.301778  대정읍
# 4  126.526362  서호동

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   업소명      167 non-null    object
#  1   소재지(지번)  167 non-null    object
#  2   위도       167 non-null    float64
#  3   경도       167 non-null    float64
#  4   읍면동      167 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 6.6+ KB

# %% [markdown]
# ## 데이터 탐색하기

# %% [markdown]
# ### 빵집이 제일 많은 동네는 어디일까?

# %%
df['읍면동'].value_counts()
# Out:
# 읍면동
# 대정읍    26
# 안덕면    23
# 성산읍    16
# 동홍동    13
# 서귀동    12
# 남원읍    10
# 표선면    10
# 하효동     9
# 중문동     9
# 서호동     8
# 법환동     6
# 서홍동     6
# 강정동     6
# 색달동     5
# 회수동     2
# 토평동     2
# 상예동     1
# 신효동     1
# 월평동     1
# 호근동     1
# Name: count, dtype: int64

# %%
# 대정읍-> 안덕면 -> 성산읍 순서로 빵집이 많다.

# %%
df.loc[df['읍면동']=='대정읍'][['업소명', '소재지(지번)']]  #읍명동이 대정읍이면서 업소명과 소재지(지번)추출
#df_t=df.loc[df['읍면동']=='대정읍']
#df_t[['업소명', '소재지(지번)']]
# Out:
#                          업소명                              소재지(지번)
# 3                       허니제과          제주특별자치도 서귀포시 대정읍 구억리 365-5
# 5              수께로(Suekkero)          제주특별자치도 서귀포시 대정읍 하모리 923-5
# 8                     소낭베이커리            제주특별자치도 서귀포시 대정읍 상모리 418
# 9                       우리제과         제주특별자치도 서귀포시 대정읍 하모리 1497-4
# 19                   제주우도슈크레    제주특별자치도 서귀포시 대정읍 보성리 2547 빌리지 더휴
# 20   베이커리픽키키(Bakery Pickiki)         제주특별자치도 서귀포시 대정읍 상모리 3854-8
# 32    버터리팬트리(BUTTERY PANTRY)         제주특별자치도 서귀포시 대정읍 하모리 1560-3
# 44         아베크아롬(AVEC AROME)            제주특별자치도 서귀포시 대정읍 구억리 980
# 55                       라퐁텐          제주특별자치도 서귀포시 대정읍 보성리 163-5
# 58                        스텔         제주특별자치도 서귀포시 대정읍 일과리 1933번지
# 68                 수애기베이커리카페        제주특별자치도 서귀포시 대정읍 동일리 3132 1층
# 76                      미쁜제과      제주특별자치도 서귀포시 대정읍 신도리 2349-13번지
# 77   베이크샵스니프(BAKESHOP SNIFF)   제주특별자치도 서귀포시 대정읍 구억리 1115 해동그린앤골드
# 84                       달콤해      제주특별자치도 서귀포시 대정읍 상모리 3938번지 1층
# 86               뚜레쥬르제주영어도시점         제주특별자치도 서귀포시 대정읍 보성리 2417번지
# 91               파리바게뜨대정하나로점  제주특별자치도 서귀포시 대정읍 상모리 3453번지 , 지하1층
# 104               뚜레쥬르제주모슬포점         제주특별자치도 서귀포시 대정읍 하모리 1293번지
# 109             파리바게트제주영어도시점         제주특별자치도 서귀포시 대정읍 보성리 2372-4
# 124                    황금륭버거             제주특별자치도 서귀포시 대정읍 신도리 10
# 125                 황금륭스마일버거        제주특별자치도 서귀포시 대정읍 신도리 11 외1필지
# 133                 파리바게뜨대정점       제주특별자치도 서귀포시 대정읍 하모리 820-16번지
# 138                   중앙베이커리       제주특별자치도 서귀포시 대정읍 하모리 2143-3번지
# 157                    신세계제과         제주특별자치도 서귀포시 대정읍 하모리 849-21
# 158                      온누리          제주특별자치도 서귀포시 대정읍 하모리 852-4
# 159                   빙그레제과점          제주특별자치도 서귀포시 대정읍 하모리 824번지
# 165   버터리팬트리(BUTTERY PANTRY)         제주특별자치도 서귀포시 대정읍 하모리 1560-3

# %% [markdown]
# ### 중문동/서호동에 있는 빵집의 주소 알아보기

# %%
# df.loc[df['읍면동']=='중문동'][['업소명', '소재지(지번)']]
df.loc[df['읍면동']=='서호동'][['업소명', '소재지(지번)']]
# Out:
#                              업소명                      소재지(지번)
# 4    도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1
# 26                      이공일(201)        제주특별자치도 서귀포시 서호동 297
# 47                      시스터필드서호점     제주특별자치도 서귀포시 서호동 1554-6
# 54                        이민욱제빵소  제주특별자치도 서귀포시 서호동 1231-9 1충
# 61                      드숑(신시가지)    제주특별자치도 서귀포시 서호동 1615-10
# 99                 채점석베이커리 혁신도시점     제주특별자치도 서귀포시 서호동 1554-4
# 108                          더심플  제주특별자치도 서귀포시 서호동 1551-10번지
# 119                 파리바게뜨서귀포월드컵점     제주특별자치도 서귀포시 서호동 1550-6

# %% [markdown]
# ## 데이터 시각화 하기
# - 지도위에 위치와 정보 표시하기
# - folium 사용법 <br>
# https://python-visualization.github.io/folium/quickstart.html#Getting-Started

# %% [markdown]
# ### folium사용하기

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium --upgrade  #-U

# %%
folium.__version__
# Out:
# '0.14.0'

# %%
# 초기위치(위도,경도)=서귀포시 33.2541205,126.560076
#lati, long  = 33.2541205,126.560076
center=(33.2541205,126.560076)
map = folium.Map(location = center, zoom_start= 10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f07536f25039ac6f09cf0f8d911f3de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f07536f25039ac6f09cf0f8d911f3de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f07536f25039ac6f09cf0f8d911f3de = L.map(
#                 &quot;map_8f07536f25039ac6f09cf0f8d911f3de&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_145ae84d4e009a29e74d922b6e3bd18d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8f07536f25039ac6f09cf0f8d911f3de);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = [ lati, long ],
                 zoom_start= 10
                 )
tooltip = 'click'
folium.Marker(
    location = [lati, long ],
    popup = '<strong>hello jeju</strong>',
    icon = folium.Icon(color = 'pink', icon = 'heart'),
    tooltip = tooltip
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15f0966b0aa889dee04279a3c89561e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15f0966b0aa889dee04279a3c89561e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15f0966b0aa889dee04279a3c89561e5 = L.map(
#                 &quot;map_15f0966b0aa889dee04279a3c89561e5&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e949c73aa01edf215e272a7f5ab2642 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15f0966b0aa889dee04279a3c89561e5);
#
#
#             var marker_ba2e3f0fb287f0c1602cd3b7589f2436 = L.marker(
#                 [33.2541205, 126.560076],
#                 {}
#             ).addTo(map_15f0966b0aa889dee04279a3c89561e5);
#
#
#             var icon_73d3b187256d670ac51ddc0124b6e154 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba2e3f0fb287f0c1602cd3b7589f2436.setIcon(icon_73d3b187256d670ac51ddc0124b6e154);
#
#
#         var popup_984ae036bdc8788cdcf9ff48a0c59e16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_197998d78f53ce8d9dbe162b48c83239 = $(`&lt;div id=&quot;html_197998d78f53ce8d9dbe162b48c83239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_984ae036bdc8788cdcf9ff48a0c59e16.setContent(html_197998d78f53ce8d9dbe162b48c83239);
#
#
#
#         marker_ba2e3f0fb287f0c1602cd3b7589f2436.bindPopup(popup_984ae036bdc8788cdcf9ff48a0c59e16)
#         ;
#
#
#
#
#             marker_ba2e3f0fb287f0c1602cd3b7589f2436.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 제과점 위치 마커 표시하기

# %%
df.head()
# Out:
#                            업소명                      소재지(지번)         위도  \
# 0           노베케이션(No Vacation)   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364
# 1            그랜드파파(Grand papa)      제주특별자치도 서귀포시 서귀동 829-5   33.246848
# 2               위드윗(withwheat)      제주특별자치도 서귀포시 서홍동 166-5   33.267520
# 3                         허니제과  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342
# 4  도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1   33.255598
#
#            경도  읍면동
# 0  126.837714  표선면
# 1  126.560673  서귀동
# 2  126.558177  서홍동
# 3  126.301778  대정읍
# 4  126.526362  서호동

# %%
df.loc[0,'위도']   #df.loc[행,열]
df.loc[5, '위도']
# Out:
# 33.22141736

# %% [markdown]
# ### 마커에 정보 넣기

# %%
for idx in df.index :
  lat = df.loc[idx,'위도']
  lng = df.loc[idx,'경도']
  marker = folium.Marker(
      location = [lat, lng],
      popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
      {df.loc[idx, '소재지(지번)']}</div>",
      icon = folium.Icon(color='orange', icon='cloud')
      )
  marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15f0966b0aa889dee04279a3c89561e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15f0966b0aa889dee04279a3c89561e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15f0966b0aa889dee04279a3c89561e5 = L.map(
#                 &quot;map_15f0966b0aa889dee04279a3c89561e5&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e949c73aa01edf215e272a7f5ab2642 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15f0966b0aa889dee04279a3c89561e5);
#
#
#             var marker_ba2e3f0fb287f0c1602cd3b7589f2436 = L.marker(
#                 [33.2541205, 126.560076],
#                 {}
#             ).addTo(map_15f0966b0aa889dee04279a3c89561e5);
#
#
#             var icon_73d3b187256d670ac51ddc0124b6e154 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba2e3f0fb287f0c1602cd3b7589f2436.setIcon(icon_73d3b187256d670ac51ddc0124b6e154);
#
#
#         var popup_984ae036bdc8788cdcf9ff48a0c59e16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_197998d78f53ce8d9dbe162b48c83239 = $(`&lt;div id=&quot;html_197998d78f53ce8d9dbe162b48c83239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_984ae036bdc8788cdcf9ff48a0c59e16.setContent(html_197998d78f53ce8d9dbe162b48c83239);
#
#
#
#         marker_ba2e3f0fb287f0c1602cd3b7589f2436.bindPopup(popup_984ae036bdc8788cdcf9ff48a0c59e16)
#         ;
#
#
#
#
#             marker_ba2e3f0fb287f0c1602cd3b7589f2436.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_558b8eebb95f432dc67873785eb8d2ac = L.marker(
#                 [33.32536384, 126.8377136],
#                 {}
#             ).addTo(map_15f0966b0aa889dee04279a3c89561e5);
#
#
#             var icon_186acad4aa4af9e5afd1685353e9f18a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_558b8eebb95f432dc67873785eb8d2ac.setIcon(icon_186acad4aa4af9e5afd1685353e9f18a);
#
#
#         var popup_fe8e5422cc0cfad31634130ceac59d57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7dfae9b1df1c4c9095aa2184456154a = $(`&lt;div id=&quot;html_e7dfae9b1df1c4c9095aa2184456154a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;노베케이션(No Vacation)&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 표선면 표선리 40-3 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_fe8e5422cc0cfad31634130ceac59d57.setContent(html_e7dfae9b1df1c4c9095aa2184456154a);
#
#
#
#         marker_558b8eebb95f432dc67873785eb8d2ac.bindPopup(popup_fe8e5422cc0cfad31634130ceac59d57)
#         ;
#
#
#
#
#             var marker_283d8d83ef2ad28f6c495de2d07243e0 = L.marker(
#                 [33.24684824, 126.5606733],
#                 {}
#             ).addTo(map_15f0966b0aa889dee04279a3c89561e5);
#
#
#             var icon_efeee15de79cf1dc73bcbde275899474 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_283d8d83ef2ad28f6c495de2d07243e0.setIcon(icon_efeee15de79cf1dc73bcbde275899474);
#
#
#         var popup_47934fa4205cb85b1ad3f45340383cda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecba90bf7f8d2441c9e99258d8fb8df0 = $(`&lt;div id=&quot;html_ecba90bf7f8d2441c9e99258d8fb8df0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;그랜드파파(Grand papa)&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 서귀동 829-5 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_47934fa4205cb85b1ad3f45340383cda.setContent(html_ecba90bf7f8d2441c9e99258d8fb8df0);

# %%
df=df.sort_values(by=['읍면동','업소명'],ascending=False)
df
# Out:
#              업소명                           소재지(지번)         위도          경도  읍면동
# 15           일일참             제주특별자치도 서귀포시 회수동 628   33.251609  126.438008  회수동
# 89            델리              제주특별자치도 서귀포시 회수동 30   33.285853  126.444624  회수동
# 122    다올베이커리2호점        제주특별자치도 서귀포시 호근동 1792-2번지   33.257496  126.526019  호근동
# 139  효돈농협하나로베이커리           제주특별자치도 서귀포시 하효동 639번지   33.260968  126.617171  하효동
# 18    테라로사 서귀포지점          제주특별자치도 서귀포시 하효동 1306-1   33.249536  126.618886  하효동
# ..           ...                               ...        ...         ...  ...
# 37          크라상점          제주특별자치도 서귀포시 강정동 207-13   33.253063  126.503547  강정동
# 103    주식회사시스터필드  제주특별자치도 서귀포시 강정동 231-2 1층 103-2호  33.248997  126.507319  강정동
# 102        봉주르마담         제주특별자치도 서귀포시 강정동 208-4번지   33.252772  126.503327  강정동
# 43       미베이커리카페             제주특별자치도 서귀포시 강정동 847   33.236002  126.498828  강정동
# 40          구우쿠다           제주특별자치도 서귀포시 강정동 143-5   33.257165  126.507996  강정동
#
# [167 rows x 5 columns]

# %%
#읍면동별로 아이콘 컬러를 다르게 설정하기
#help(folium.Icon)

df=df.sort_values(by=['읍면동','업소명'],ascending=False)

colors=['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']
v_idx=0
v_color='orange'
v_읍면동=df.loc[v_idx,'읍면동']  #기준
for idx in df.index :
    #아이콘 색상 다르게 지정(읍면동별로)
    if df.loc[idx,'읍면동']==v_읍면동:
        v_color=colors[v_idx]
    else:
        #컬러의 색상을 모두 사용하면 다시 처음으로
        if len(colors)-1==v_idx:
            v_idx=0
        else:
            v_idx+=1
        v_color=colors[v_idx]
        v_읍면동=df.loc[idx,'읍면동']

    lat = df.loc[idx,'위도']
    lng = df.loc[idx,'경도']
    marker = folium.Marker(
        location = [lat, lng],
        popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
        {df.loc[idx, '소재지(지번)']}</div>",
        icon = folium.Icon(color=v_color, icon='cloud')
        )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a0d3c77bf874623846ce08e4318e7ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a0d3c77bf874623846ce08e4318e7ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a0d3c77bf874623846ce08e4318e7ed = L.map(
#                 &quot;map_4a0d3c77bf874623846ce08e4318e7ed&quot;,
#                 {
#                     center: [33.3616666, 126.5291666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5bf9798293b72b1c57bfbcf1284334b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a0d3c77bf874623846ce08e4318e7ed);
#
#
#             var marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c = L.markerClusterGroup(
#                 {}
#             );
#             map_4a0d3c77bf874623846ce08e4318e7ed.addLayer(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var marker_546d014a837f8302f10d8aa2afb9d774 = L.marker(
#                 [33.25160856, 126.4380083],
#                 {}
#             ).addTo(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var icon_cc131acc5878f8294f5a1e7054568015 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_546d014a837f8302f10d8aa2afb9d774.setIcon(icon_cc131acc5878f8294f5a1e7054568015);
#
#
#         var popup_2b04f923d376317e5f7e1b45496450d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a04c1d836c383b93c232c80a0b2095b = $(`&lt;div id=&quot;html_4a04c1d836c383b93c232c80a0b2095b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;일일참&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 회수동 628 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_2b04f923d376317e5f7e1b45496450d8.setContent(html_4a04c1d836c383b93c232c80a0b2095b);
#
#
#
#         marker_546d014a837f8302f10d8aa2afb9d774.bindPopup(popup_2b04f923d376317e5f7e1b45496450d8)
#         ;
#
#
#
#
#             var marker_0c840226d587fb5d2d6457568e8925eb = L.marker(
#                 [33.2858527, 126.4446235],
#                 {}
#             ).addTo(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var icon_168f33005306e56dda9bb99acf312e6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c840226d587fb5d2d6457568e8925eb.setIcon(icon_168f33005306e56dda9bb99acf312e6a);
#
#
#         var popup_58c861ce36bca50467b39ee6dbbdbb38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abeaef3b70df5b1f8523ad577f758638 = $(`&lt;div id=&quot;html_abeaef3b70df5b1f8523ad577f758638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;델리&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 회수동 30 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_58c861ce36bca50467b39ee6dbbdbb38.setContent(html_abeaef3b70df5b1f8523ad577f758638);
#
#
#
#         marker_0c840226d587fb5d2d6457568e8925eb.bindPopup(popup_58c861ce36bca50467b39ee6dbbdbb38)
#         ;
#
#
#
#
#             var marker_80f5a4da25c0948cc131f57f04642e4d = L.marker(
#                 [33.25749646, 126.5260187],
#                 {}
#             ).addTo(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var icon_650ae52e9bb4c2183c90365a1f2accaa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_80f5a4da25c0948cc131f57f04642e4d.setIcon(icon_650ae52e9bb4c2183c90365a1f2accaa);
#
#
#         var popup_

# %%
from folium.plugins import MarkerCluster

map = folium.Map(location = [33.3616666,126.5291666 ],
                 zoom_start= 10
                 )

marker_cluster = MarkerCluster().add_to(map)

for idx in df.index :
  lat = df.loc[idx,'위도']
  lng = df.loc[idx,'경도']
  marker = folium.Marker(
      location = [lat, lng],
      popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
      {df.loc[idx, '소재지(지번)']}</div>",
      icon = folium.Icon(color='orange', icon='cloud')
      )
  marker.add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a0d3c77bf874623846ce08e4318e7ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a0d3c77bf874623846ce08e4318e7ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a0d3c77bf874623846ce08e4318e7ed = L.map(
#                 &quot;map_4a0d3c77bf874623846ce08e4318e7ed&quot;,
#                 {
#                     center: [33.3616666, 126.5291666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5bf9798293b72b1c57bfbcf1284334b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a0d3c77bf874623846ce08e4318e7ed);
#
#
#             var marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c = L.markerClusterGroup(
#                 {}
#             );
#             map_4a0d3c77bf874623846ce08e4318e7ed.addLayer(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var marker_546d014a837f8302f10d8aa2afb9d774 = L.marker(
#                 [33.25160856, 126.4380083],
#                 {}
#             ).addTo(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var icon_cc131acc5878f8294f5a1e7054568015 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_546d014a837f8302f10d8aa2afb9d774.setIcon(icon_cc131acc5878f8294f5a1e7054568015);
#
#
#         var popup_2b04f923d376317e5f7e1b45496450d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a04c1d836c383b93c232c80a0b2095b = $(`&lt;div id=&quot;html_4a04c1d836c383b93c232c80a0b2095b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;일일참&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 회수동 628 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_2b04f923d376317e5f7e1b45496450d8.setContent(html_4a04c1d836c383b93c232c80a0b2095b);
#
#
#
#         marker_546d014a837f8302f10d8aa2afb9d774.bindPopup(popup_2b04f923d376317e5f7e1b45496450d8)
#         ;
#
#
#
#
#             var marker_0c840226d587fb5d2d6457568e8925eb = L.marker(
#                 [33.2858527, 126.4446235],
#                 {}
#             ).addTo(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var icon_168f33005306e56dda9bb99acf312e6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c840226d587fb5d2d6457568e8925eb.setIcon(icon_168f33005306e56dda9bb99acf312e6a);
#
#
#         var popup_58c861ce36bca50467b39ee6dbbdbb38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abeaef3b70df5b1f8523ad577f758638 = $(`&lt;div id=&quot;html_abeaef3b70df5b1f8523ad577f758638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;델리&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 회수동 30 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_58c861ce36bca50467b39ee6dbbdbb38.setContent(html_abeaef3b70df5b1f8523ad577f758638);
#
#
#
#         marker_0c840226d587fb5d2d6457568e8925eb.bindPopup(popup_58c861ce36bca50467b39ee6dbbdbb38)
#         ;
#
#
#
#
#             var marker_80f5a4da25c0948cc131f57f04642e4d = L.marker(
#                 [33.25749646, 126.5260187],
#                 {}
#             ).addTo(marker_cluster_6f93910e7d45d2eaa5cc0b76a38fb25c);
#
#
#             var icon_650ae52e9bb4c2183c90365a1f2accaa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_80f5a4da25c0948cc131f57f04642e4d.setIcon(icon_650ae52e9bb4c2183c90365a1f2accaa);
#
#
#         var popup_
